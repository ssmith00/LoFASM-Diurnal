# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# %%
dd00 = np.load('20190624_000931_CC.bbx.gz.npy')
dd0 = np.load('20190624_001434_CC.bbx.gz.npy')
dd1 = np.load('20190624_001937_CC.bbx.gz.npy')
dd2 = np.load('20190624_002441_CC.bbx.gz.npy')
dd3 = np.load('20190624_002944_CC.bbx.gz.npy')
dd4 = np.load('20190624_003447_CC.bbx.gz.npy')
dd5 = np.load('20190624_003950_CC.bbx.gz.npy')

dd = np.append((dd00.T),dd0.T, axis=1)
dd = np.append((dd),dd1.T, axis=1)
dd = np.append((dd),dd2.T, axis=1)
dd = np.append((dd),dd3.T, axis=1)
dd = np.append((dd),dd4.T, axis=1)
dd = np.append((dd),dd5.T, axis=1)
dd.shape
# Out:
# (1024, 25305)

# %%
fig, ax = plt.subplots()

plt.setp(ax, xticks=[0,596.047,1192.094,1788.141,2384.188,2980.235,3576.282],
         xticklabels=['0','50','100','150','200','250','300'],
         yticks=[184,225,266,307,348,389,430,471,512,552,593,634,675,716,757],
         yticklabels=['18','22','26','30','34','38','42','46','50','54','58','62','66','70','74'])

plt.xlabel('Time (s)')
plt.ylabel('Frequency (MHz)')
plt.title('6/15/2019, 01:04:38')
#ylim(512,675)

ax.yaxis.label.set_size(15)
ax.xaxis.label.set_size(15)
ax.title.set_size(20)

fig.set_size_inches(30,10.5)

 


 

plt.imshow(10*np.log10(dd), aspect='auto', origin='lower', vmax=5e1)
# Out:
# /home/shane/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
